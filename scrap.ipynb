# %%
for link in soup.find_all('a',href=True):  # in html anchor/link is represented by the tag <a>

    print(link.get('href'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_377/2649287674.py in <module>
# ----> 1 for link in soup.find_all('a',href=True):  # in html anchor/link is represented by the tag <a>
#       2
#       3     print(link.get('href'))
#
# NameError: name 'soup' is not defined

# %%
h_elements =soup.find_all('tr')

titles = [td.get_text(strip=True) for td in h_elements]

print(titles[1:10])

# %%
for link in soup.find_all('img'):# in html image is represented by the tag <img>
   # print(link)
   # print(link.get('src'))

# %%
h3_elements =soup.find_all('h3')

titles = [h3.get_text() for h3 in h3_elements]

print(titles)

# %%
import requests
from bs4 import BeautifulSoup

# Send a GET request to the URL
url = "https://en.wikipedia.org/wiki/List_of_highest-grossing_films"
response = requests.get(url)

# Create a BeautifulSoup object to parse the HTML content
soup = BeautifulSoup(response.content, 'html.parser')

# Find the table element
table = soup.find('table', class_='wikitable')

# Extract the rows from the table
rows = table.find_all('tr')

# Initialize an empty list to store the table data
data = []

# Iterate over the rows and extract the cell data
for row in rows:
    cells = row.find_all('td')
    row_data = [cell.get_text(strip=True) for cell in cells]
    data.append(row_data)

# Print the extracted table data
for row in data:
    print(row)
# Out:
# []
# ['1', '1', '$2,923,706,026', '2009', '[# 1][# 2]']
# ['2', '1', '$2,797,501,328', '2019', '[# 3][# 4]']
# ['3', '3', '$2,320,250,281', '2022', '[# 5][# 6]']
# ['4', '1', 'T$2,257,844,554', '1997', '[# 7][# 8]']
# ['5', '3', '$2,068,223,624', '2015', '[# 9][# 10]']
# ['6', '4', '$2,048,359,754', '2018', '[# 11][# 12]']
# ['7', '6', '$1,921,847,111', '2021', '[# 13][# 14]']
# ['8', '3', '$1,671,537,444', '2015', '[# 15][# 16]']
# ['9', '7', '$1,656,943,394', '2019', '[# 17][# 4]']
# ['10', '3', '$1,518,815,515', '2012', '[# 18][# 19]']
# ['11', '4', '$1,515,341,399', '2015', '[# 20][# 21]']
# ['12', '11', '$1,493,491,858', '2022', '[# 22][# 23]']
# ['13', '10', '$1,450,026,933', '2019', '[# 24][# 25]']
# ['14', '5', '$1,402,809,540', '2015', '[# 26][# 21]']
# ['15', '9', '$1,347,280,838', '2018', '[# 27][# 28]']
# ['16', '3', '$1,342,139,727', '2011', '[# 29][# 30]']
# ['17', '9', '$1,332,539,889', '2017', '[# 31][# 32]']
# ['18', '18', '$1,313,370,737', '2023', '[# 33][# 34]']
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Send a GET request to the URL
url = "https://en.wikipedia.org/wiki/List_of_highest-grossing_films"
response = requests.get(url)

# Create a BeautifulSoup object to parse the HTML content
soup = BeautifulSoup(response.content, 'html.parser')

# Find the table element
table = soup.find('table', class_='wikitable')

# Extract the rows from the table
rows = table.find_all('tr')

# Initialize an empty list to store the table data
data = []

# Iterate over the rows and extract the cell data
for row in rows:
    cells = row.find_all(['th', 'td'])
    row_data = [cell.get_text(strip=True) for cell in cells]
    data.append(row_data)

# Remove empty rows
data = [row for row in data if row]

# Create a DataFrame from the table data
df = pd.DataFrame(data[1:], columns=data[0])

# Print the DataFrame
print(df)
# Out:
#    Rank  Peak                                          Title  \
# 0     1     1                                         Avatar
# 1     2     1                              Avengers: Endgame
# 2     3     3                       Avatar: The Way of Water
# 3     4     1                                        Titanic
# 4     5     3                   Star Wars: The Force Awakens
# 5     6     4                         Avengers: Infinity War
# 6     7     6                        Spider-Man: No Way Home
# 7     8     3                                 Jurassic World
# 8     9     7                                  The Lion King
# 9    10     3                                   The Avengers
# 10   11     4                                      Furious 7
# 11   12    11                              Top Gun: Maverick
# 12   13    10                                      Frozen II
# 13   14     5                        Avengers: Age of Ultron
# ...

# %%
table = soup.find_all('table', class_='wikitable')
print(table[0])
# Out:
# <table class="wikitable sortable plainrowheaders" style="margin:auto; margin:auto;">
# <caption>Highest-grossing films<sup class="reference" id="cite_ref-12"><a href="#cite_note-12">[12]</a></sup>
# </caption>
# <tbody><tr>
# <th scope="col">Rank
# </th>
# <th scope="col">Peak
# </th>
# <th scope="col">Title
# </th>
# <th scope="col">Worldwide gross
# </th>
# <th scope="col">Year
# </th>
# <th class="unsortable" scope="col">Reference(s)
# </th></tr>
# <tr>
# <td>1
# </td>
# <td>1
# </td>
# <th scope="row"><i><a href="/wiki/Avatar_(2009_film)" title="Avatar (2009 film)">Avatar</a></i>
# </th>
# <td align="right">$2,923,706,026
# </td>
# <td style="text-align:center;">2009
# </td>
# <td style="text-align:center;"><sup class="reference" id="cite_ref-avatar_13-0"><a href="#cite_note-avatar-13">[# 1]</a></sup><sup class="reference" id="cite_ref-avatar_peak_14-0"><a href="#cite_note-avatar_peak-14">[# 2]</a></sup>
# </td></tr>
# <tr>
# <td>2
# </td>
# <td>1
# </td>
# ...

# %%
for row in table.find('tr'): # in html table row is represented by the tag <tr>
    # Get all columns in each row.
    cols = row.find_all('td') # in html a column is represented by the tag <td>
    Title= cols[2].string # store the value in column 3 as color_name
    Worldwide_gross = cols[3].string # store the value in column 4 as color_code
    print("{}--->{}".format(Title,Worldwide_gross))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_377/4115205086.py in <module>
# ----> 1 for row in table.find('tr'): # in html table row is represented by the tag <tr>
#       2     # Get all columns in each row.
#       3     cols = row.find_all('td') # in html a column is represented by the tag <td>
#       4     Title= cols[2].string # store the value in column 3 as color_name
#       5     Worldwide_gross = cols[3].string # store the value in column 4 as color_code
#
# ~/conda/envs/python/lib/python3.7/site-packages/bs4/element.py in __getattr__(self, key)
#    2288         """Raise a helpful exception to explain a common code fix."""
#    2289         raise AttributeError(
# ...

# %%
soup.find_all('title')
# Out:
# [<title>List of highest-grossing films - Wikipedia</title>]

# %%
#W=soup.find('tr')
#d=W.next_sibling
#e=d.next_sibling
#z=e.next_sibling
#z.next_sibling

a=soup.find_all('th')[0:10]
a
# Out:
# [<th scope="col">Rank
#  </th>,
#  <th scope="col">Peak
#  </th>,
#  <th scope="col">Title
#  </th>,
#  <th scope="col">Worldwide gross
#  </th>,
#  <th scope="col">Year
#  </th>,
#  <th class="unsortable" scope="col">Reference(s)
#  </th>,
#  <th scope="row"><i><a href="/wiki/Avatar_(2009_film)" title="Avatar (2009 film)">Avatar</a></i>
#  </th>,
#  <th scope="row"><i><a href="/wiki/Avengers:_Endgame" title="Avengers: Endgame">Avengers: Endgame</a></i>
#  </th>,
#  <th scope="row" style="background:#b6fcb6;"><i><a href="/wiki/Avatar:_The_Way_of_Water" title="Avatar: The Way of Water">Avatar: The Way of Water</a></i> <img alt="film currently playing" data-file-height="14" data-file-width="9" decoding="async" height="14" src="//upload.wikimedia.org/wikipedia/commons/3/37/Dagger-14-plain.png" width="9"/>
#  </th>,
#  <th scope="row"><i><a href="/wiki/Titanic_(1997_film)" title="Titanic (1997 film)">Titanic</a></i>
#  </th>]

# %%
a=soup.get_text('td',strip=True)[1:10]
a
# Out:
# 'ist of hi'

# %% [markdown]
# # all table

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
url="https://en.wikipedia.org/wiki/List_of_highest-grossing_films"
data  = requests.get(url).text 
soup = BeautifulSoup(data,"html.parser")



data = []
rows = soup.find_all('tr')
# Iterate over the rows and extract the cell data
for row in rows:
    cells = row.find_all(['th', 'td'])
    row_data = [cell.get_text(strip=True) for cell in cells]
    data.append(row_data)
#data[0:15]
X=pd.DataFrame(data)
X.head()
# Out:
#     0     1                         2                3     4             5    \
# 0  Rank  Peak                     Title  Worldwide gross  Year  Reference(s)
# 1     1     1                    Avatar   $2,923,706,026  2009    [# 1][# 2]
# 2     2     1         Avengers: Endgame   $2,797,501,328  2019    [# 3][# 4]
# 3     3     3  Avatar: The Way of Water   $2,320,250,281  2022    [# 5][# 6]
# 4     4     1                   Titanic  T$2,257,844,554  1997    [# 7][# 8]
#
#     6     7     8     9    ...   142   143   144   145   146   147   148  \
# 0  None  None  None  None  ...  None  None  None  None  None  None  None
# 1  None  None  None  None  ...  None  None  None  None  None  None  None
# 2  None  None  None  None  ...  None  None  None  None  None  None  None
# 3  None  None  None  None  ...  None  None  None  None  None  None  None
# 4  None  None  None  None  ...  None  None  None  None  None  None  None
#
#     149   150   151
# 0  None  None  None
# 1  None  None  None
# ...

# %% [markdown]
# ## first table

# %%
E=X[0:51]

E1=E.drop(E.columns[5:152],axis=1)
E2=E1.drop(E.columns[1],axis=1)

E2.head()
E3=E2
#E3 = E2.set_index(E2.columns[0]).rename_axis(None, axis=1)

E3.columns = E3.iloc[0]
E3 =E3[1:]
E3

E4= E3.set_index('Rank')

# %%
E5=E4
E5['Worldwide gross']=E5['Worldwide gross'].str.replace('T', '')
E5['Worldwide gross']=E5['Worldwide gross'].str.replace('HP1', '')
E5['Worldwide gross']=E5['Worldwide gross'].str.replace('F', '')
E5['Worldwide gross']=E5['Worldwide gross'].str.replace('F8', '')
import re

E5['Worldwide gross'] =E5['Worldwide gross'].str.replace(r'^8', '')#   THis is for removing 8 from infront of 23  
E5
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: The default value of regex will change from True to False in a future version.
# 0                                             Title Worldwide gross  Year
# Rank
# 1                                            Avatar  $2,923,706,026  2009
# 2                                 Avengers: Endgame  $2,797,501,328  2019
# 3                          Avatar: The Way of Water  $2,320,250,281  2022
# 4                                           Titanic  $2,257,844,554  1997
# 5                      Star Wars: The Force Awakens  $2,068,223,624  2015
# 6                            Avengers: Infinity War  $2,048,359,754  2018
# 7                           Spider-Man: No Way Home  $1,921,847,111  2021
# 8                                    Jurassic World  $1,671,537,444  2015
# 9                                     The Lion King  $1,656,943,394  2019
# ...

# %% [markdown]
# ##  SQL

# %%
import sqlite3

# !pip install ipython-sql
con=sqlite3.connect('SQL1.db')
#E5.to_sql('mov',con)
# %load_ext sql
# %sql sqlite:///SQL1.db
# Out:
# ...
# 'Connected: @SQL1.db'

# %% [markdown]
# ## second table

# %%
QW=X[51:62]

# %%
QW=QW.drop(QW.columns[4:152],axis=1)
QW

dea=headers1
QW.columns =dea
QW

AS=QW.drop(QW.index[0],axis=0)
AS

AS =AS.reset_index(drop=True)


AS = AS.set_index('Rank')
AS
# Out:
#                              Title        Worldwide gross(2022 $)  Year
# Rank
# 1               Gone with the Wind                 $4,192,000,000  1939
# 2                           Avatar               A1$3,824,000,000  2009
# 3                          Titanic  $2,516,000,000T$3,485,000,000  1997
# 4                        Star Wars                 $3,443,000,000  1977
# 5                Avengers: Endgame               AE$3,165,000,000  2019
# 6               The Sound of Music                 $2,884,000,000  1965
# 7       E.T. the Extra-Terrestrial                 $2,815,000,000  1982
# 8             The Ten Commandments                 $2,665,000,000  1956
# 9                   Doctor Zhivago                 $2,526,000,000  1965
# 10    Star Wars: The Force Awakens              TFA$2,491,000,000  2015

# %%
ww = [wws.replace('$2,516,000,000', '').replace('A1', '').replace('AE', '').replace('T', '').replace('FA', '') for wws in AS.iloc[:, 1]]	
ww1=pd.DataFrame(ww)
ww1
zx=AS
zx
zx.iloc[:, 1]=ww
zx
# Out:
#                              Title Worldwide gross(2022 $)  Year
# Rank
# 1               Gone with the Wind          $4,192,000,000  1939
# 2                           Avatar          $3,824,000,000  2009
# 3                          Titanic          $3,485,000,000  1997
# 4                        Star Wars          $3,443,000,000  1977
# 5                Avengers: Endgame          $3,165,000,000  2019
# 6               The Sound of Music          $2,884,000,000  1965
# 7       E.T. the Extra-Terrestrial          $2,815,000,000  1982
# 8             The Ten Commandments          $2,665,000,000  1956
# 9                   Doctor Zhivago          $2,526,000,000  1965
# 10    Star Wars: The Force Awakens          $2,491,000,000  2015

# %% [markdown]
# # scrapping

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
url="https://en.wikipedia.org/wiki/List_of_highest-grossing_films"
data  = requests.get(url).text 
soup = BeautifulSoup(data,"html.parser")

# %%
tables = soup.find_all('table')
for index,table in enumerate(tables):
    if ("Highest-grossing films as of 2022 adjusted for inflation" in str(table)):
            table_index = index
print(index)
# Out:
# 88

# %%
#D=print(tables[1].prettify())
D=tables[1]
print(D.prettify())
# Out:
# <table class="wikitable plainrowheaders" style="margin:auto; margin:auto;">
#  <caption>
#   <span class="nowrap">
#    Highest-grossing films as of 2022
#    <sup class="plainlinks noexcerpt noprint asof-tag update" style="display:none;">
#     <a class="external text" href="https://en.wikipedia.org/w/index.php?title=List_of_highest-grossing_films&amp;action=edit">
#      [update]
#     </a>
#    </sup>
#    adjusted for inflation
#    <sup class="reference" id="cite_ref-Guinness_2015_117-0">
#     <a href="#cite_note-Guinness_2015-117">
#      [35]
#     </a>
#    </sup>
#   </span>
#   <sup class="reference" id="ref_Inflation">
#    <a href="#endnote_Inflation">
#     [Inf]
#    </a>
#   </sup>
#  </caption>
#  <tbody>
#   <tr>
#    <th scope="col">
#     Rank
#    </th>
#    <th scope="col">
#     Title
#    </th>
#    <th data-sort-type="currency" scope="col">
#     <div style="display: inline-block; line-height: 1.2em; padding: .1em 0;">
#      Worldwide gross
#      <br/>
# ...

# %%
headers1= [th.get_text(strip=True) for th in D.find_all('th')[0:4]]
headers1

df1 = pd.DataFrame(headers1)
df1
# Out:
#                          0
# 0                     Rank
# 1                    Title
# 2  Worldwide gross(2022 $)
# 3                     Year

# %%
headers2= [th.get_text(strip=True) for th in D.find_all('th')[4:15]]
headers2

df2 = pd.DataFrame(headers2)

# %%
ww= [td.get_text(strip=True)for td in D.find_all('td')[1:30:3]]
ww = [wws.replace('$2,516,000,000', '').replace('A1', '').replace('AE', '').replace('T', '').replace('FA', '') for wws in ww]
ww=pd.DataFrame(ww)

# %%
year= [td.get_text(strip=True)for td in D.find_all('td')[2:30:3]]
year
year=pd.DataFrame(year)

# %%
rank= [td.get_text(strip=True)for td in D.find_all('td')[0:30:3]]
rank=pd.DataFrame(rank)

# %%
zz= pd.concat([rank,df2,ww,year],axis=1)

# %%
dea=headers1
zz.columns =dea
zz.head()
# Out:
#   Rank               Title Worldwide gross(2022 $)  Year
# 0    1  Gone with the Wind          $4,192,000,000  1939
# 1    2              Avatar          $3,824,000,000  2009
# 2    3             Titanic          $3,485,000,000  1997
# 3    4           Star Wars          $3,443,000,000  1977
# 4    5   Avengers: Endgame          $3,165,000,000  2019

# %%
FB =zz.set_index('Rank')
FB
# Out:
#                              Title Worldwide gross(2022 $)  Year
# Rank
# 1               Gone with the Wind          $4,192,000,000  1939
# 2                           Avatar          $3,824,000,000  2009
# 3                          Titanic          $3,485,000,000  1997
# 4                        Star Wars          $3,443,000,000  1977
# 5                Avengers: Endgame          $3,165,000,000  2019
# 6               The Sound of Music          $2,884,000,000  1965
# 7       E.T. the Extra-Terrestrial          $2,815,000,000  1982
# 8             The Ten Commandments          $2,665,000,000  1956
# 9                   Doctor Zhivago          $2,526,000,000  1965
# 10    Star Wars: The Force Awakens          $2,491,000,000  2015

# %% [markdown]
# ## 3rd table

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
url="https://en.wikipedia.org/wiki/List_of_highest-grossing_films"
data  = requests.get(url).text 
soup = BeautifulSoup(data,"html.parser")

# %%
shift function
